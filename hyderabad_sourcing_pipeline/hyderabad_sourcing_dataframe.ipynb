# %%
import pandas as pd
company_data = [
    {"Estimated_Company_Name": "MTAR Technologies", "Website_URL": "https://mtar.in", "Segment": "Aerospace / Precision Engineering"},
    {"Estimated_Company_Name": "Arrow Engineering Industries", "Website_URL": "https://www.aeipl.co", "Segment": "Aerospace / Precision Engineering"},
    {"Estimated_Company_Name": "Azad Engineering", "Website_URL": "https://azad.in", "Segment": "Aerospace / Precision Engineering"},
    {"Estimated_Company_Name": "Vimta Labs", "Website_URL": "https://www.vimta.com", "Segment": "Specialty Diagnostics & Life Sciences"},
    {"Estimated_Company_Name": "Neuland Laboratories", "Website_URL": "https://www.neulandlabs.com", "Segment": "Complex APIs"},
    {"Estimated_Company_Name": "Virchow Biotech", "Website_URL": "https://virchowbiotech.com", "Segment": "Specialty Biotech"},
    {"Estimated_Company_Name": "Excelra", "Website_URL": "https://www.excelra.com", "Segment": "Specialty Biotech"},
    {"Estimated_Company_Name": "Itaan Pharma", "Website_URL": "https://www.itaanpharma.com", "Segment": "Specialty Biotech"},
    {"Estimated_Company_Name": "Shantha Biotechnics", "Website_URL": "https://www.sanofi.in", "Segment": "Specialty Biotech"},
    {"Estimated_Company_Name": "Glukem Biocare", "Website_URL": "http://www.glukem.com", "Segment": "Complex APIs"}
]

# %%
df_raw = pd.DataFrame(company_data)

columns_to_add = [
    "E1_Producer_Pass", "E2_Accessible_Pass", 
    "C3_Differentiated", "C4_Decision_Maker", 
    "C5_Growing_Sector", "C6_Growth_Signals", 
    "C7_Systems_Maturity", "C8_Leadership_Succession"
]

for col in columns_to_add:
    df_raw[col] = ""
csv_filename = "hyderabad_target_companies_raw.csv"
df_raw.to_csv(csv_filename, index=False)

print(f"Success! {len(df_raw)} companies saved to {csv_filename}.")
display(df_raw.head())
# Out:
# Success! 10 companies saved to hyderabad_target_companies_raw.csv.
#          Estimated_Company_Name                  Website_URL  \
# 0             MTAR Technologies              https://mtar.in
# 1  Arrow Engineering Industries         https://www.aeipl.co
# 2              Azad Engineering              https://azad.in
# 3                    Vimta Labs        https://www.vimta.com
# 4          Neuland Laboratories  https://www.neulandlabs.com
#
#                                  Segment E1_Producer_Pass E2_Accessible_Pass  \
# 0      Aerospace / Precision Engineering
# 1      Aerospace / Precision Engineering
# 2      Aerospace / Precision Engineering
# 3  Specialty Diagnostics & Life Sciences
# 4                           Complex APIs
#
#   C3_Differentiated C4_Decision_Maker C5_Growing_Sector C6_Growth_Signals  \
# 0
# 1
# 2
# 3
# 4
#
#   C7_Systems_Maturity C8_Leadership_Succession
# 0
# 1
# 2
# 3
# 4

# %%
int_columns = [
    'c3_differentiated', 'c4_decision_maker', 'c5_growing_sector', 
    'c6_growth_signals', 'c7_systems_maturity', 'c8_leadership_succession'
]

for col in int_columns:
    df_raw[col] = 0

df_raw['e1_producer_pass'] = 'PENDING'
df_raw['e2_accessible_pass'] = 'PENDING'

try:
    df_raw.to_sql('target_companies', con=engine, if_exists='append', index=False)
    print("Success! Type mismatch resolved and data injected into PostgreSQL.")
except Exception as e:
    print(f"Database Error: {e}")
# Out:
# Success! Type mismatch resolved and data injected into PostgreSQL.

# %%
int_cols = ['c3_differentiated', 'c4_decision_maker', 'c5_growing_sector', 
            'c6_growth_signals', 'c7_systems_maturity', 'c8_leadership_succession']

for col in int_cols:
    df_raw[col] = 0

df_raw['e1_producer_pass'] = 'PENDING'
df_raw['e2_accessible_pass'] = 'PENDING'

df_raw['research_evidence'] = ""
df_raw['overall_verdict'] = "Under Review"

try:
    df_raw.to_sql('target_companies', con=engine, if_exists='append', index=False)
    print("Success! All rows have been successfully injected into PostgreSQL with proper integer types.")
except Exception as e:
    print(f"Database Error: {e}")
# Out:
# Success! All rows have been successfully injected into PostgreSQL with proper integer types.

# %%
import pandas as pd
from sqlalchemy import create_engine

extra_companies = [
    {"company_name": "Bharat Biotech", "segment": "Specialty Biotech", "website_url": "https://www.bharatbiotech.com", "research_evidence": "Disqualified on size: Generates over Rs. 1000Cr in revenue. Exceeds the target mid-market Rs. 50Cr–500Cr sweet spot.", "overall_verdict": "Disqualified"},
    {"company_name": "Biological E", "segment": "Specialty Biotech", "website_url": "https://www.biologicale.com", "research_evidence": "Disqualified on size: Large-scale global vaccine manufacturer exceeding the Rs. 50Cr-500Cr mid-market criteria.", "overall_verdict": "Disqualified"},
    {"company_name": "Laurus Labs", "segment": "Complex APIs", "website_url": "https://www.lauruslabs.com", "research_evidence": "Disqualified on size: Revenue exceeds Rs. 5000Cr, pushing it far beyond the required MSME/mid-market scope.", "overall_verdict": "Disqualified"},
    {"company_name": "Indian Immunologicals", "segment": "Animal Health & Veterinary", "website_url": "https://www.indimmune.com", "research_evidence": "Operates advanced veterinary biologicals and vaccine manufacturing facilities in Hyderabad within the target market caps."},
    {"company_name": "Lee Pharma", "segment": "Complex APIs", "website_url": "http://www.leepharma.com", "research_evidence": "Manufactures specialized APIs and intermediate formulations with dedicated production units in Hyderabad."},
    {"company_name": "Suven Life Sciences", "segment": "Specialty Biotech", "website_url": "https://www.suven.com", "research_evidence": "Focuses on premium drug discovery and clinical research assets, remaining promoter-driven and separate from Suven Pharma."},
    {"company_name": "Celon Labs", "segment": "Complex APIs", "website_url": "https://www.celonlabs.com", "research_evidence": "Manufactures niche oncology and critical care specialty pharmaceutical formulations in Hyderabad."},
    {"company_name": "Symed Labs", "segment": "Complex APIs", "website_url": "http://www.symedlabs.com", "research_evidence": "Operates multiple USFDA-approved manufacturing sites in Hyderabad focusing on complex active pharmaceutical ingredients."},
    {"company_name": "Maithri Drugs", "segment": "Complex APIs", "website_url": "http://www.maithridrugs.com", "research_evidence": "An active manufacturer of complex APIs and intermediates with established production infrastructure in Hyderabad."},
    {"company_name": "Vasant Chemicals", "segment": "Custom Synthesis & Specialty Chemicals", "website_url": "https://www.vasantchem.com", "research_evidence": "Provides custom synthesis and specialty chemical manufacturing services to global clients from Hyderabad facilities."},
    {"company_name": "Sura Labs", "segment": "Specialty Diagnostics & Life-Science Tools", "website_url": "http://www.suralabs.com", "research_evidence": "Manufactures analytical testing reagents and diagnostic lab tools in-house for biotech infrastructures."},
    {"company_name": "Prinhac", "segment": "Specialty Food & Nutraceutical Ingredients", "website_url": "https://www.prinhac.com", "research_evidence": "Produces specialized plant-based protein extracts and functional nutraceutical ingredients in Hyderabad."},
    {"company_name": "Ananth Technologies", "segment": "Precision Engineering & Aerospace", "website_url": "https://www.ananthtech.com", "research_evidence": "Textbook Federer. Scientist-founder manufacturing high-precision satellite systems and avionics subsystems for ISRO."},
    {"company_name": "Medha Servo Drives", "segment": "Industrial Sensors & Instrumentation", "website_url": "https://www.medhaservo.com", "research_evidence": "Designs and manufactures heavy control electronics and traction powertrains for locomotive transport networks."},
    {"company_name": "Zen Technologies", "segment": "Industrial Sensors & Instrumentation", "website_url": "https://www.zentechnologies.com", "research_evidence": "Designs and manufactures indigenous military combat simulators and counter-drone systems at its hardware park plant."}
]

df_extra = pd.DataFrame(extra_companies)

int_columns = ['c3_differentiated', 'c4_decision_maker', 'c5_growing_sector', 'c6_growth_signals', 'c7_systems_maturity', 'c8_leadership_succession']
for col in int_columns:
    df_extra[col] = 0

df_extra['e1_producer_pass'] = 'PENDING'
df_extra['e2_accessible_pass'] = 'PENDING'
df_extra['overall_verdict'] = 'Fit'

df_extra.loc[df_extra['overall_verdict'] == 'Disqualified', 'e1_producer_pass'] = 'FAIL'

DATABASE_URL = "postgresql://postgres:zoro897@localhost:5432/hyderabad companies db8"
engine = create_engine(DATABASE_URL)

try:
    df_extra.to_sql('target_companies', con=engine, if_exists='append', index=False)
    print("Success! 15 additional companies safely injected. Your dataset is now complete.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! 15 additional companies safely injected. Your dataset is now complete.
